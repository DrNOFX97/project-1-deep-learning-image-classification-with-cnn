# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models, optimizers, Input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import seaborn as sns

# Function to calculate evaluation metrics
def calculate_metrics(y_true, y_pred):
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, average='macro', zero_division=1)
    recall = recall_score(y_true, y_pred, average='macro', zero_division=1)
    f1 = f1_score(y_true, y_pred, average='macro', zero_division=1)
    return accuracy, precision, recall, f1

# Function to plot confusion matrix
def plot_confusion_matrix(y_true, y_pred, classes):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=classes, yticklabels=classes)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')
    plt.show()

# Check available devices
physical_devices = tf.config.list_physical_devices()
if "GPU" in [device.device_type for device in physical_devices]:
    device_info = "GPU acceleration in place powered by TensorFlow (GPU)"
else:
    device_info = "Using CPU... Best of luck..."
print(device_info)

# Load CIFAR-10 dataset
(x_train, y_train), (x_test, y_test) = datasets.cifar10.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

# Data augmentation
datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True
)
datagen.fit(x_train)

# Define the VGG16 model
base_model = tf.keras.applications.VGG16(include_top=False, weights='imagenet', input_shape=(32, 32, 3))
base_model.trainable = False  # Freeze the pre-trained weights

# Adding classification layers on top
flatten_layer = layers.Flatten()
dense_layer = layers.Dense(256, activation='relu')
dropout_layer = layers.Dropout(0.5)
output_layer = layers.Dense(10, activation='softmax')

# Construct the model
inputs = Input(shape=(32, 32, 3))
x = base_model(inputs, training=False)
x = flatten_layer(x)
x = dense_layer(x)
x = dropout_layer(x)
outputs = output_layer(x)
model = models.Model(inputs, outputs)

# Compile the model
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# Set up early stopping and learning rate reduction on plateau
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.00001)

# Train the model with augmented data
history = model.fit(datagen.flow(x_train, y_train, batch_size=128),
                    epochs=50,
                    validation_data=(x_test, y_test),
                    callbacks=[early_stopping, reduce_lr])

# Evaluate the model on the test dataset
test_loss, test_accuracy = model.evaluate(x_test, y_test)
print(f'Test accuracy: {test_accuracy:.4f}')

# Plot the training curves
plt.figure(figsize=(12, 5))

# Loss curve
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()

# Accuracy curve
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

plt.show()

# Make predictions
y_pred = np.argmax(model.predict(x_test), axis=-1)

# Calculate evaluation metrics
accuracy, precision, recall, f1 = calculate_metrics(y_test, y_pred)

# Print detailed statistics
print("Detailed Statistics:")
print(f"Test Accuracy: {accuracy * 100:.2f}%")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1 Score: {f1:.2f}")

# Plot confusion matrix
classes = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
plot_confusion_matrix(y_test, y_pred, classes)
# Out:
# GPU acceleration in place powered by TensorFlow (GPU)
# 2024-06-09 20:06:44.818883: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1
# 2024-06-09 20:06:44.818922: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2024-06-09 20:06:44.818931: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2024-06-09 20:06:44.819150: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-06-09 20:06:44.819170: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Epoch 1/50
# 2024-06-09 20:06:45.609014: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 61ms/step - accuracy: 0.3410 - loss: 1.8503 - val_accuracy: 0.5272 - val_loss: 1.3490 - learning_rate: 0.0010
# Epoch 2/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 23s 59ms/step - accuracy: 0.4940 - loss: 1.4478 - val_accuracy: 0.5552 - val_loss: 1.2628 - learning_rate: 0.0010
# Epoch 3/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 23s 58ms/step - accuracy: 0.5130 - loss: 1.3847 - val_accuracy: 0.5606 - val_loss: 1.2373 - learning_rate: 0.0010
# Epoch 4/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 23s 58ms/step - accuracy: 0.5254 - loss: 1.3497 - val_accuracy: 0.5729 - val_loss: 1.2157 - learning_rate: 0.0010
# Epoch 5/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 23s 58ms/step - accuracy: 0.5402 - loss: 1.3164 - val_accuracy: 0.5755 - val_loss: 1.2040 - learning_rate: 0.0010
# Epoch 6/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 23s 58ms/step - accuracy: 0.5410 - loss: 1.2968 - val_accuracy: 0.5801 - val_loss: 1.1929 - learning_rate: 0.0010
# Epoch 7/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 23s 58ms/step - accuracy: 0.5518 - loss: 1.2788 - val_accuracy: 0.5846 - val_loss: 1.1803 - learning_rate: 0.0010
# Epoch 8/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 23s 58ms/step - accuracy: 0.5508 - loss: 1.2748 - val_accuracy: 0.5880 - val_loss: 1.1606 - learning_rate: 0.0010
# Epoch 9/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 23s 58ms/step - accuracy: 0.5540 - loss: 1.2708 - val_accuracy: 0.5870 - val_loss: 1.1658 - learning_rate: 0.0010
# Epoch 10/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 23s 58ms/step - accuracy: 0.5557 - loss: 1.2643 - val_accuracy: 0.5866 - val_loss: 1.1688 - learning_rate: 0.0010
# Epoch 11/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 23s 59ms/step - accuracy: 0.5625 - loss: 1.2451 - val_accuracy: 0.5956 - val_loss: 1.1474 - learning_rate: 0.0010
# Epoch 12/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 23s 58ms/step - accuracy: 0.5659 - loss: 1.2431 - val_accuracy: 0.5982 - val_loss: 1.1537 - learning_rate: 0.0010
# Epoch 13/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 23s 58ms/step - accuracy: 0.5677 - loss: 1.2332 - val_accuracy: 0.5994 - val_loss: 1.1381 - learning_rate: 0.0010
# Epoch 14/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 23s 58ms/step - accuracy: 0.5685 - loss: 1.2235 - val_accuracy: 0.6039 - val_loss: 1.1423 - learning_rate: 0.0010
# Epoch 15/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 23s 58ms/step - accuracy: 0.5719 - loss: 1.2302 - val_accuracy: 0.5993 - val_loss: 1.1525 - learning_rate: 0.0010
# Epoch 16/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 23s 58ms/step - accuracy: 0.5713 - loss: 1.2241 - val_accuracy: 0.5993 - val_loss: 1.1453 - learning_rate: 0.0010
# Epoch 17/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 23s 58ms/step - accuracy: 0.5738 - loss: 1.2151 - val_accuracy: 0.6048 - val_loss: 1.1261 - learning_rate: 0.0010
# Epoch 18/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 23s 58ms/step - accuracy: 0.5790 - loss: 1.2072 - val_accuracy: 0.6047 - val_loss: 1.1290 - learning_rate: 0.0010
# Epoch 19/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 23s 58ms/step - accuracy: 0.5739 - loss: 1.2131 - val_accuracy: 0.6070 - val_loss: 1.1252 - learning_rate: 0.0010
# Epoch 20/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 23s 59ms/step - accuracy: 0.5825 - loss: 1.1926 - val_accuracy: 0.6113 - val_loss: 1.1168 - learning_rate: 0.0010
# Epoch 21/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 23s 59ms/step - accuracy: 0.5754 - loss: 1.2089 - val_accuracy: 0.6099 - val_loss: 1.1246 - learning_rate: 0.0010
# Epoch 22/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 23s 58ms/step - accuracy: 0.5847 - loss: 1.1905 - val_accuracy: 0.6099 - val_loss: 1.1107 - learning_rate: 0.0010
# Epoch 23/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 23s 58ms/step - accuracy: 0.5867 - loss: 1.1858 - val_accuracy: 0.6128 - val_loss: 1.1101 - learning_rate: 0.0010
# Epoch 24/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 23s 57ms/step - accuracy: 0.5865 - loss: 1.1858 - val_accuracy: 0.6072 - val_loss: 1.1211 - learning_rate: 0.0010
# Epoch 25/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 23s 58ms/step - accuracy: 0.5833 - loss: 1.1856 - val_accuracy: 0.6098 - val_loss: 1.1146 - learning_rate: 0.0010
# Epoch 26/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 23s 58ms/step - accuracy: 0.5846 - loss: 1.1739 - val_accuracy: 0.6093 - val_loss: 1.1185 - learning_rate: 0.0010
# Epoch 27/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 23s 58ms/step - accuracy: 0.5894 - loss: 1.1741 - val_accuracy: 0.6082 - val_loss: 1.1128 - learning_rate: 0.0010
# Epoch 28/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 23s 58ms/step - accuracy: 0.5837 - loss: 1.1834 - val_accuracy: 0.6158 - val_loss: 1.1122 - learning_rate: 0.0010
# Epoch 29/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 23s 59ms/step - accuracy: 0.5938 - loss: 1.1560 - val_accuracy: 0.6173 - val_loss: 1.0995 - learning_rate: 2.0000e-04
# Epoch 30/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 23s 58ms/step - accuracy: 0.5999 - loss: 1.1448 - val_accuracy: 0.6196 - val_loss: 1.0949 - learning_rate: 2.0000e-04
# Epoch 31/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 23s 58ms/step - accuracy: 0.6029 - loss: 1.1362 - val_accuracy: 0.6197 - val_loss: 1.0918 - learning_rate: 2.0000e-04
# Epoch 32/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 23s 58ms/step - accuracy: 0.6012 - loss: 1.1381 - val_accuracy: 0.6206 - val_loss: 1.0918 - learning_rate: 2.0000e-04
# Epoch 33/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 23s 58ms/step - accuracy: 0.6041 - loss: 1.1270 - val_accuracy: 0.6213 - val_loss: 1.0948 - learning_rate: 2.0000e-04
# Epoch 34/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 27s 69ms/step - accuracy: 0.5993 - loss: 1.1384 - val_accuracy: 0.6201 - val_loss: 1.0942 - learning_rate: 2.0000e-04
# Epoch 35/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 29s 74ms/step - accuracy: 0.6067 - loss: 1.1296 - val_accuracy: 0.6217 - val_loss: 1.0894 - learning_rate: 2.0000e-04
# Epoch 36/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 29s 73ms/step - accuracy: 0.6058 - loss: 1.1226 - val_accuracy: 0.6202 - val_loss: 1.0903 - learning_rate: 2.0000e-04
# Epoch 37/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 29s 74ms/step - accuracy: 0.6045 - loss: 1.1242 - val_accuracy: 0.6212 - val_loss: 1.0889 - learning_rate: 2.0000e-04
# Epoch 38/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 28s 71ms/step - accuracy: 0.6054 - loss: 1.1279 - val_accuracy: 0.6240 - val_loss: 1.0858 - learning_rate: 2.0000e-04
# Epoch 39/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 28s 71ms/step - accuracy: 0.6036 - loss: 1.1317 - val_accuracy: 0.6201 - val_loss: 1.0865 - learning_rate: 2.0000e-04
# Epoch 40/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 29s 73ms/step - accuracy: 0.6096 - loss: 1.1172 - val_accuracy: 0.6192 - val_loss: 1.0900 - learning_rate: 2.0000e-04
# Epoch 41/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 28s 71ms/step - accuracy: 0.6074 - loss: 1.1167 - val_accuracy: 0.6239 - val_loss: 1.0820 - learning_rate: 2.0000e-04
# Epoch 42/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 28s 71ms/step - accuracy: 0.6064 - loss: 1.1242 - val_accuracy: 0.6208 - val_loss: 1.0877 - learning_rate: 2.0000e-04
# Epoch 43/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 29s 73ms/step - accuracy: 0.6101 - loss: 1.1092 - val_accuracy: 0.6204 - val_loss: 1.0877 - learning_rate: 2.0000e-04
# Epoch 44/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 29s 73ms/step - accuracy: 0.6052 - loss: 1.1191 - val_accuracy: 0.6215 - val_loss: 1.0830 - learning_rate: 2.0000e-04
# Epoch 45/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 28s 71ms/step - accuracy: 0.6125 - loss: 1.1120 - val_accuracy: 0.6222 - val_loss: 1.0790 - learning_rate: 2.0000e-04
# Epoch 46/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 28s 72ms/step - accuracy: 0.6082 - loss: 1.1233 - val_accuracy: 0.6230 - val_loss: 1.0857 - learning_rate: 2.0000e-04
# Epoch 47/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 29s 72ms/step - accuracy: 0.6110 - loss: 1.1111 - val_accuracy: 0.6228 - val_loss: 1.0874 - learning_rate: 2.0000e-04
# Epoch 48/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 29s 72ms/step - accuracy: 0.6125 - loss: 1.1094 - val_accuracy: 0.6219 - val_loss: 1.0835 - learning_rate: 2.0000e-04
# Epoch 49/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 28s 72ms/step - accuracy: 0.6146 - loss: 1.1143 - val_accuracy: 0.6219 - val_loss: 1.0843 - learning_rate: 2.0000e-04
# Epoch 50/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 29s 73ms/step - accuracy: 0.6129 - loss: 1.1042 - val_accuracy: 0.6228 - val_loss: 1.0847 - learning_rate: 2.0000e-04
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 6s 20ms/step - accuracy: 0.6218 - loss: 1.0776
# Test accuracy: 0.6222
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 13ms/step
# Detailed Statistics:
# Test Accuracy: 62.22%
# Precision: 0.62
# Recall: 0.62
# F1 Score: 0.62
