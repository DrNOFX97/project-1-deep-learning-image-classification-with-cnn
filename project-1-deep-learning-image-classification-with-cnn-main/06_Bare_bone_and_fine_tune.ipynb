# %% [markdown]
# # 1. Make predictions on a pre-trained model
# ## Key Points:
# 1. Data Loading and Preprocessing: Loads the CIFAR-10 dataset, normalizes the data, and one-hot encodes the labels.
# 2. Model Definition: Loads the pre-trained VGG16 model without the top layer and adds custom dense layers for CIFAR-10 classification.
# 3. Layer Freezing: Freezes all layers of the VGG16 base model to prevent them from being trained (no fine-tuning).
# 4. Model Compilation: Compiles the model with the Adam optimizer and categorical cross-entropy loss.
# 5. Training with Progress Bar: Trains the model with a progress bar for visual feedback.
# 6. Evaluation: Evaluates the model on the test dataset and prints out the performance metrics in a tabulated format.
# * This code represents a minimalistic approach to transfer learning, where the pre-trained model is used as a feature extractor without any further training of its layers.

# %%
import os
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Sequential
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import precision_score, recall_score, f1_score
import numpy as np
import matplotlib.pyplot as plt

# Suppress TensorFlow warnings
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

# Load CIFAR-10 dataset
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# Normalize the data
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# One-hot encode the labels
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Define the custom model architecture
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(32, 32, 3)),
    MaxPooling2D(pool_size=(2, 2)),
    Conv2D(64, (3, 3), activation='relu', padding='same'),
    MaxPooling2D(pool_size=(2, 2)),
    Conv2D(128, (3, 3), activation='relu', padding='same'),
    MaxPooling2D(pool_size=(2, 2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(10, activation='softmax')  # CIFAR-10 has 10 classes
])

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Print the model summary
model.summary()

# Set training parameters
num_epochs = 50
batch_size = 64

# Train the model
print("Training the model")
history = model.fit(x_train, y_train, batch_size=batch_size, epochs=num_epochs, validation_data=(x_test, y_test), verbose=1)

# Evaluate the model on the test dataset
loss, accuracy = model.evaluate(x_test, y_test, verbose=0)

# Print the final evaluation metrics
print(f'Test Loss: {loss:.4f}')
print(f'Test Accuracy: {accuracy:.4f}')

# Make predictions on the test set
y_pred = model.predict(x_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_test_classes = np.argmax(y_test, axis=1)

# Calculate precision, recall, and F1 score
precision = precision_score(y_test_classes, y_pred_classes, average='weighted', zero_division=1)
recall = recall_score(y_test_classes, y_pred_classes, average='weighted', zero_division=1)
f1 = f1_score(y_test_classes, y_pred_classes, average='weighted', zero_division=1)

# Print the precision, recall, and F1 score
print(f'Precision: {precision:.4f}')
print(f'Recall: {recall:.4f}')
print(f'F1 Score: {f1:.4f}')

# Plot the training and validation accuracy and loss
plt.figure(figsize=(14, 6))

# Accuracy plot
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Loss plot
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 8, 8, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 356,810 (1.36 MB)
#  Trainable params: 356,810 (1.36 MB)
#  Non-trainable params: 0 (0.00 B)
# Training the model
# Epoch 1/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 23s 28ms/step - accuracy: 0.3710 - loss: 1.7227 - val_accuracy: 0.5945 - val_loss: 1.1417
# Epoch 2/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 22s 28ms/step - accuracy: 0.6228 - loss: 1.0668 - val_accuracy: 0.6358 - val_loss: 1.0207
# Epoch 3/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 23s 30ms/step - accuracy: 0.6931 - loss: 0.8786 - val_accuracy: 0.7058 - val_loss: 0.8506
# Epoch 4/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 23s 29ms/step - accuracy: 0.7325 - loss: 0.7595 - val_accuracy: 0.7181 - val_loss: 0.8280
# Epoch 5/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 22s 28ms/step - accuracy: 0.7660 - loss: 0.6709 - val_accuracy: 0.7241 - val_loss: 0.8096
# Epoch 6/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 23s 29ms/step - accuracy: 0.7914 - loss: 0.5934 - val_accuracy: 0.7232 - val_loss: 0.8094
# Epoch 7/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 22s 28ms/step - accuracy: 0.8143 - loss: 0.5288 - val_accuracy: 0.7345 - val_loss: 0.7935
# Epoch 8/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 22s 28ms/step - accuracy: 0.8410 - loss: 0.4533 - val_accuracy: 0.7191 - val_loss: 0.8549
# Epoch 9/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 21s 27ms/step - accuracy: 0.8584 - loss: 0.4043 - val_accuracy: 0.7257 - val_loss: 0.8687
# Epoch 10/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 23s 30ms/step - accuracy: 0.8774 - loss: 0.3486 - val_accuracy: 0.7306 - val_loss: 0.8935
# Epoch 11/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 24s 31ms/step - accuracy: 0.8954 - loss: 0.2968 - val_accuracy: 0.7367 - val_loss: 0.9342
# Epoch 12/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 23s 30ms/step - accuracy: 0.9119 - loss: 0.2540 - val_accuracy: 0.7313 - val_loss: 1.0121
# Epoch 13/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 23s 30ms/step - accuracy: 0.9206 - loss: 0.2271 - val_accuracy: 0.7375 - val_loss: 1.0512
# Epoch 14/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 23s 30ms/step - accuracy: 0.9322 - loss: 0.1916 - val_accuracy: 0.7286 - val_loss: 1.1473
# Epoch 15/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 22s 29ms/step - accuracy: 0.9410 - loss: 0.1652 - val_accuracy: 0.7290 - val_loss: 1.2016
# Epoch 16/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 22s 28ms/step - accuracy: 0.9533 - loss: 0.1357 - val_accuracy: 0.7255 - val_loss: 1.3279
# Epoch 17/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 22s 28ms/step - accuracy: 0.9501 - loss: 0.1364 - val_accuracy: 0.7232 - val_loss: 1.3650
# Epoch 18/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 22s 28ms/step - accuracy: 0.9618 - loss: 0.1083 - val_accuracy: 0.7249 - val_loss: 1.4305
# Epoch 19/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 22s 28ms/step - accuracy: 0.9599 - loss: 0.1092 - val_accuracy: 0.7294 - val_loss: 1.4763
# Epoch 20/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 22s 28ms/step - accuracy: 0.9589 - loss: 0.1180 - val_accuracy: 0.7181 - val_loss: 1.6081
# Epoch 21/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 22s 28ms/step - accuracy: 0.9623 - loss: 0.1084 - val_accuracy: 0.7257 - val_loss: 1.6153
# Epoch 22/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 22s 28ms/step - accuracy: 0.9656 - loss: 0.0961 - val_accuracy: 0.7234 - val_loss: 1.6937
# Epoch 23/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 21s 27ms/step - accuracy: 0.9678 - loss: 0.0925 - val_accuracy: 0.7147 - val_loss: 1.7654
# Epoch 24/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 22s 28ms/step - accuracy: 0.9692 - loss: 0.0858 - val_accuracy: 0.7168 - val_loss: 1.7104
# Epoch 25/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 22s 28ms/step - accuracy: 0.9727 - loss: 0.0777 - val_accuracy: 0.7219 - val_loss: 1.8227
# Epoch 26/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 22s 28ms/step - accuracy: 0.9720 - loss: 0.0814 - val_accuracy: 0.7224 - val_loss: 1.8743
# Epoch 27/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 22s 28ms/step - accuracy: 0.9754 - loss: 0.0687 - val_accuracy: 0.7194 - val_loss: 2.0466
# Epoch 28/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 22s 28ms/step - accuracy: 0.9751 - loss: 0.0746 - val_accuracy: 0.7205 - val_loss: 2.0166
# Epoch 29/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 23s 29ms/step - accuracy: 0.9743 - loss: 0.0728 - val_accuracy: 0.7274 - val_loss: 1.9914
# Epoch 30/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 22s 29ms/step - accuracy: 0.9805 - loss: 0.0569 - val_accuracy: 0.7127 - val_loss: 2.0399
# Epoch 31/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 22s 28ms/step - accuracy: 0.9756 - loss: 0.0708 - val_accuracy: 0.7237 - val_loss: 2.1584
# Epoch 32/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 22s 28ms/step - accuracy: 0.9755 - loss: 0.0743 - val_accuracy: 0.7198 - val_loss: 2.1249
# Epoch 33/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 28ms/step - accuracy: 0.9774 - loss: 0.0663 - val_accuracy: 0.7199 - val_loss: 2.1512
# Epoch 34/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 22s 28ms/step - accuracy: 0.9783 - loss: 0.0650 - val_accuracy: 0.7240 - val_loss: 2.1665
# Epoch 35/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 22s 28ms/step - accuracy: 0.9753 - loss: 0.0706 - val_accuracy: 0.7187 - val_loss: 2.2123
# Epoch 36/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 22s 29ms/step - accuracy: 0.9829 - loss: 0.0518 - val_accuracy: 0.7129 - val_loss: 2.3954
# Epoch 37/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 22s 28ms/step - accuracy: 0.9765 - loss: 0.0670 - val_accuracy: 0.7222 - val_loss: 2.2910
# Epoch 38/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 22s 28ms/step - accuracy: 0.9762 - loss: 0.0708 - val_accuracy: 0.7132 - val_loss: 2.3948
# Epoch 39/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 22s 28ms/step - accuracy: 0.9792 - loss: 0.0632 - val_accuracy: 0.7295 - val_loss: 2.3170
# Epoch 40/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 22s 29ms/step - accuracy: 0.9808 - loss: 0.0574 - val_accuracy: 0.7191 - val_loss: 2.4299
# Epoch 41/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 22s 28ms/step - accuracy: 0.9787 - loss: 0.0647 - val_accuracy: 0.7271 - val_loss: 2.4594
# Epoch 42/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 22s 28ms/step - accuracy: 0.9823 - loss: 0.0502 - val_accuracy: 0.7165 - val_loss: 2.6041
# Epoch 43/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 22s 28ms/step - accuracy: 0.9810 - loss: 0.0584 - val_accuracy: 0.7217 - val_loss: 2.3724
# Epoch 44/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 22s 28ms/step - accuracy: 0.9808 - loss: 0.0560 - val_accuracy: 0.7159 - val_loss: 2.4797
# Epoch 45/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 22s 29ms/step - accuracy: 0.9815 - loss: 0.0556 - val_accuracy: 0.7201 - val_loss: 2.6488
# Epoch 46/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 22s 28ms/step - accuracy: 0.9792 - loss: 0.0625 - val_accuracy: 0.7195 - val_loss: 2.5546
# Epoch 47/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 22s 29ms/step - accuracy: 0.9810 - loss: 0.0575 - val_accuracy: 0.7250 - val_loss: 2.5504
# Epoch 48/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 23s 29ms/step - accuracy: 0.9861 - loss: 0.0440 - val_accuracy: 0.7286 - val_loss: 2.4327
# Epoch 49/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 23s 29ms/step - accuracy: 0.9835 - loss: 0.0508 - val_accuracy: 0.7247 - val_loss: 2.5990
# Epoch 50/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 22s 29ms/step - accuracy: 0.9802 - loss: 0.0612 - val_accuracy: 0.7188 - val_loss: 2.7023
# Test Loss: 2.7023
# Test Accuracy: 0.7188
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
# Precision: 0.7221
# Recall: 0.7188
# F1 Score: 0.7169

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import precision_score, recall_score, f1_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Suppress TensorFlow warnings
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'

# Load CIFAR-10 dataset
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# Normalize the data
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# One-hot encode the labels
y_train_onehot = to_categorical(y_train, 10)
y_test_onehot = to_categorical(y_test, 10)

# Define the custom model architecture
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(32, 32, 3)),
    MaxPooling2D(pool_size=(2, 2)),
    Conv2D(64, (3, 3), activation='relu', padding='same'),
    MaxPooling2D(pool_size=(2, 2)),
    Conv2D(128, (3, 3), activation='relu', padding='same'),
    MaxPooling2D(pool_size=(2, 2)),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),  # Added dropout to help with regularization
    Dense(10, activation='softmax')  # CIFAR-10 has 10 classes
])

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Print the model summary
model.summary()

# Set training parameters
num_epochs = 50
batch_size = 64

# Train the model
print("Training the model")
history = model.fit(x_train, y_train_onehot, batch_size=batch_size, epochs=num_epochs, validation_data=(x_test, y_test_onehot), verbose=1)

# Evaluate the model on the test dataset
loss, accuracy = model.evaluate(x_test, y_test_onehot, verbose=0)

# Print the final evaluation metrics
print(f'Test Loss: {loss:.4f}')
print(f'Test Accuracy: {accuracy:.4f}')

# Make predictions on the test set
y_pred = model.predict(x_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_test_classes = y_test.flatten()

# Calculate precision, recall, and F1 score
precision = precision_score(y_test_classes, y_pred_classes, average='weighted', zero_division=1)
recall = recall_score(y_test_classes, y_pred_classes, average='weighted', zero_division=1)
f1 = f1_score(y_test_classes, y_pred_classes, average='weighted', zero_division=1)

# Print the precision, recall, and F1 score
print(f'Precision: {precision:.4f}')
print(f'Recall: {recall:.4f}')
print(f'F1 Score: {f1:.4f}')

# Display classification report
print("\nClassification Report:")
print(classification_report(y_test_classes, y_pred_classes, target_names=[
    'airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']))

# Plot the training and validation accuracy and loss
plt.figure(figsize=(14, 6))

# Accuracy plot
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Loss plot
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.show()

# Confusion Matrix
conf_matrix = confusion_matrix(y_test_classes, y_pred_classes)
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=[
    'airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck'],
    yticklabels=[
    'airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck'])
plt.title('Confusion Matrix')
plt.ylabel('True Class')
plt.xlabel('Predicted Class')
plt.show()
# Out:
# Training the model
# Epoch 1/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 38s 24ms/step - accuracy: 0.4047 - loss: 1.7357 - val_accuracy: 0.5278 - val_loss: 1.3803
# Epoch 2/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 36s 23ms/step - accuracy: 0.5482 - loss: 1.3309 - val_accuracy: 0.5500 - val_loss: 1.3042
# Epoch 3/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 37s 24ms/step - accuracy: 0.5657 - loss: 1.2605 - val_accuracy: 0.5614 - val_loss: 1.2676
# Epoch 4/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 38s 24ms/step - accuracy: 0.5786 - loss: 1.2266 - val_accuracy: 0.5663 - val_loss: 1.2474
# Epoch 5/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 38s 24ms/step - accuracy: 0.5857 - loss: 1.2046 - val_accuracy: 0.5747 - val_loss: 1.2310
# Epoch 6/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 37s 24ms/step - accuracy: 0.5989 - loss: 1.1776 - val_accuracy: 0.5786 - val_loss: 1.2219
# Epoch 7/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 38s 24ms/step - accuracy: 0.5978 - loss: 1.1669 - val_accuracy: 0.5760 - val_loss: 1.2169
# Epoch 8/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 41s 26ms/step - accuracy: 0.5975 - loss: 1.1644 - val_accuracy: 0.5788 - val_loss: 1.2055
# Epoch 9/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 38s 24ms/step - accuracy: 0.5997 - loss: 1.1525 - val_accuracy: 0.5768 - val_loss: 1.2055
# Epoch 10/10
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 38s 24ms/step - accuracy: 0.6087 - loss: 1.1360 - val_accuracy: 0.5786 - val_loss: 1.2043
# Test Loss: 1.2043
# Test Accuracy: 0.5786
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step
# Precision: 0.5816
# Recall: 0.5786
# F1 Score: 0.5774

# %% [markdown]
# # Fine-tune the pre-trained model
# ## Key Points:
# 1. **Data Loading and Preprocessing**: Loads the CIFAR-10 dataset, normalizes the data, and one-hot encodes the labels.
# 2. **Model Definition**: Loads the pre-trained VGG16 model without the top layer and adds custom dense layers for CIFAR-10 classification.
# 3. **Layer Freezing**: Initially freezes all layers of the VGG16 base model to prevent them from being trained during the initial training phase.
# 4. **Initial Training**: Trains the model with the base model layers frozen.
# 5. **Layer Unfreezing**: Unfreezes the last 4 layers of the base model for fine-tuning.
# 6. **Fine-Tuning Training**: Trains the model with some of the base model layers unfrozen.
# 7. **Evaluation**: Evaluates the model on the test dataset and prints out the performance metrics in a tabulated format.
# * This approach allows the model to first learn the new task with the pre-trained weights and then fine-tune some of the deeper layers for potentially better performance.

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Sequential
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Define the custom model architecture
def create_custom_model():
    model = Sequential([
        Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(32, 32, 3)),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2, 2)),
        
        Conv2D(64, (3, 3), activation='relu', padding='same'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2, 2)),
        
        Conv2D(128, (3, 3), activation='relu', padding='same'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2, 2)),
        
        Flatten(),
        Dense(256, activation='relu'),
        Dropout(0.5),  # Added dropout to help with regularization
        Dense(10, activation='softmax')  # CIFAR-10 has 10 classes
    ])
    
    return model

# Create the model instance
model = create_custom_model()

# Print the model summary
model.summary()

# Load CIFAR-10 dataset
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# Normalize the data
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# One-hot encode the labels
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Compile the model for initial training
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model for 50 epochs
history_initial = model.fit(x_train, y_train, epochs=50, batch_size=64, validation_data=(x_test, y_test))

# Compile the model for fine-tuning with a reduced learning rate
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5), loss='categorical_crossentropy', metrics=['accuracy'])

# Fine-tune the model for additional 20 epochs
history_fine_tune = model.fit(x_train, y_train, epochs=20, batch_size=64, validation_data=(x_test, y_test))

# Evaluate the model on the test dataset
test_loss, test_accuracy = model.evaluate(x_test, y_test, verbose=0)
print(f"Final Test Loss: {test_loss:.4f}")
print(f"Final Test Accuracy: {test_accuracy:.4f}")

# Combine histories for plotting
history_combined = {
    'loss': history_initial.history['loss'] + history_fine_tune.history['loss'],
    'val_loss': history_initial.history['val_loss'] + history_fine_tune.history['val_loss'],
    'accuracy': history_initial.history['accuracy'] + history_fine_tune.history['accuracy'],
    'val_accuracy': history_initial.history['val_accuracy'] + history_fine_tune.history['val_accuracy'],
}

# Plot Loss
plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
plt.plot(history_combined['loss'], label='Train Loss')
plt.plot(history_combined['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()

# Plot Accuracy
plt.subplot(1, 2, 2)
plt.plot(history_combined['accuracy'], label='Train Accuracy')
plt.plot(history_combined['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# Predict on the test set
y_pred = model.predict(x_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_test_classes = np.argmax(y_test, axis=1)

# Generate confusion matrix
conf_matrix = confusion_matrix(y_test_classes, y_pred_classes)

# Plot confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=range(10), yticklabels=range(10))
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# Calculate detailed metrics
precision = precision_score(y_test_classes, y_pred_classes, average='weighted', zero_division=1)
recall = recall_score(y_test_classes, y_pred_classes, average='weighted', zero_division=1)
f1 = f1_score(y_test_classes, y_pred_classes, average='weighted', zero_division=1)

# Print the metrics
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)               │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 8, 8, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 8, 8, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 256)            │       524,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 621,258 (2.37 MB)
#  Trainable params: 620,810 (2.37 MB)
#  Non-trainable params: 448 (1.75 KB)
# Epoch 1/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 42s 49ms/step - accuracy: 0.3748 - loss: 1.8184 - val_accuracy: 0.5470 - val_loss: 1.2623
# Epoch 2/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 37s 47ms/step - accuracy: 0.5722 - loss: 1.2011 - val_accuracy: 0.6103 - val_loss: 1.1909
# Epoch 3/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 45ms/step - accuracy: 0.6585 - loss: 0.9837 - val_accuracy: 0.6694 - val_loss: 0.9629
# Epoch 4/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 36s 47ms/step - accuracy: 0.7107 - loss: 0.8290 - val_accuracy: 0.6622 - val_loss: 0.9822
# Epoch 5/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 45ms/step - accuracy: 0.7407 - loss: 0.7417 - val_accuracy: 0.7302 - val_loss: 0.7931
# Epoch 6/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 36s 46ms/step - accuracy: 0.7701 - loss: 0.6572 - val_accuracy: 0.7128 - val_loss: 0.8261
# Epoch 7/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 37s 47ms/step - accuracy: 0.7919 - loss: 0.5897 - val_accuracy: 0.7516 - val_loss: 0.7429
# Epoch 8/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 45ms/step - accuracy: 0.8142 - loss: 0.5353 - val_accuracy: 0.7062 - val_loss: 0.9223
# Epoch 9/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 37s 47ms/step - accuracy: 0.8330 - loss: 0.4776 - val_accuracy: 0.7286 - val_loss: 0.8847
# Epoch 10/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 36s 46ms/step - accuracy: 0.8480 - loss: 0.4366 - val_accuracy: 0.7476 - val_loss: 0.8207
# Epoch 11/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 36s 46ms/step - accuracy: 0.8580 - loss: 0.4067 - val_accuracy: 0.7098 - val_loss: 1.0332
# Epoch 12/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 37s 48ms/step - accuracy: 0.8659 - loss: 0.3747 - val_accuracy: 0.7663 - val_loss: 0.7913
# Epoch 13/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 44ms/step - accuracy: 0.8800 - loss: 0.3388 - val_accuracy: 0.7009 - val_loss: 1.1879
# Epoch 14/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 37s 47ms/step - accuracy: 0.8886 - loss: 0.3165 - val_accuracy: 0.7548 - val_loss: 0.9180
# Epoch 15/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 36s 46ms/step - accuracy: 0.8971 - loss: 0.2918 - val_accuracy: 0.7269 - val_loss: 1.0110
# Epoch 16/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 36s 46ms/step - accuracy: 0.9033 - loss: 0.2740 - val_accuracy: 0.7711 - val_loss: 0.8496
# Epoch 17/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 37s 47ms/step - accuracy: 0.9082 - loss: 0.2562 - val_accuracy: 0.7693 - val_loss: 0.8686
# Epoch 18/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 44ms/step - accuracy: 0.9166 - loss: 0.2391 - val_accuracy: 0.7556 - val_loss: 1.0534
# Epoch 19/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 37s 47ms/step - accuracy: 0.9164 - loss: 0.2382 - val_accuracy: 0.7760 - val_loss: 0.9128
# Epoch 20/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 45ms/step - accuracy: 0.9243 - loss: 0.2152 - val_accuracy: 0.7301 - val_loss: 1.1835
# Epoch 21/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 36s 46ms/step - accuracy: 0.9274 - loss: 0.2102 - val_accuracy: 0.7805 - val_loss: 0.9289
# Epoch 22/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 37s 47ms/step - accuracy: 0.9301 - loss: 0.1991 - val_accuracy: 0.7631 - val_loss: 0.9798
# Epoch 23/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 44ms/step - accuracy: 0.9298 - loss: 0.1999 - val_accuracy: 0.7789 - val_loss: 0.9596
# Epoch 24/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 42s 45ms/step - accuracy: 0.9380 - loss: 0.1784 - val_accuracy: 0.7630 - val_loss: 1.0637
# Epoch 25/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 38s 48ms/step - accuracy: 0.9370 - loss: 0.1791 - val_accuracy: 0.7851 - val_loss: 0.9848
# Epoch 26/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 38s 48ms/step - accuracy: 0.9412 - loss: 0.1689 - val_accuracy: 0.7757 - val_loss: 0.9880
# Epoch 27/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 36s 46ms/step - accuracy: 0.9427 - loss: 0.1697 - val_accuracy: 0.7428 - val_loss: 1.2928
# Epoch 28/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 37s 48ms/step - accuracy: 0.9424 - loss: 0.1615 - val_accuracy: 0.7717 - val_loss: 1.2139
# Epoch 29/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 45ms/step - accuracy: 0.9481 - loss: 0.1510 - val_accuracy: 0.7435 - val_loss: 1.1739
# Epoch 30/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 36s 46ms/step - accuracy: 0.9475 - loss: 0.1522 - val_accuracy: 0.7873 - val_loss: 1.0653
# Epoch 31/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 45ms/step - accuracy: 0.9512 - loss: 0.1413 - val_accuracy: 0.7708 - val_loss: 1.1697
# Epoch 32/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 45ms/step - accuracy: 0.9516 - loss: 0.1413 - val_accuracy: 0.7780 - val_loss: 1.0889
# Epoch 33/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 36s 47ms/step - accuracy: 0.9523 - loss: 0.1383 - val_accuracy: 0.7637 - val_loss: 1.2879
# Epoch 34/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 44ms/step - accuracy: 0.9524 - loss: 0.1365 - val_accuracy: 0.7827 - val_loss: 1.0823
# Epoch 35/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 38s 48ms/step - accuracy: 0.9545 - loss: 0.1318 - val_accuracy: 0.7257 - val_loss: 1.7114
# Epoch 36/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 36s 46ms/step - accuracy: 0.9561 - loss: 0.1269 - val_accuracy: 0.7786 - val_loss: 1.1375
# Epoch 37/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 37s 47ms/step - accuracy: 0.9575 - loss: 0.1225 - val_accuracy: 0.7629 - val_loss: 1.3256
# Epoch 38/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 37s 48ms/step - accuracy: 0.9567 - loss: 0.1264 - val_accuracy: 0.7666 - val_loss: 1.3350
# Epoch 39/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 44ms/step - accuracy: 0.9584 - loss: 0.1198 - val_accuracy: 0.7823 - val_loss: 1.1187
# Epoch 40/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 37s 48ms/step - accuracy: 0.9587 - loss: 0.1205 - val_accuracy: 0.7842 - val_loss: 1.2465
# Epoch 41/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 45ms/step - accuracy: 0.9623 - loss: 0.1096 - val_accuracy: 0.7854 - val_loss: 1.1934
# Epoch 42/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 45ms/step - accuracy: 0.9619 - loss: 0.1163 - val_accuracy: 0.7676 - val_loss: 1.3266
# Epoch 43/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 36s 46ms/step - accuracy: 0.9610 - loss: 0.1113 - val_accuracy: 0.7783 - val_loss: 1.3335
# Epoch 44/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 36s 46ms/step - accuracy: 0.9637 - loss: 0.1096 - val_accuracy: 0.7855 - val_loss: 1.1802
# Epoch 45/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 44ms/step - accuracy: 0.9658 - loss: 0.0988 - val_accuracy: 0.7599 - val_loss: 1.4702
# Epoch 46/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 37s 48ms/step - accuracy: 0.9644 - loss: 0.1034 - val_accuracy: 0.7895 - val_loss: 1.1484
# Epoch 47/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 36s 46ms/step - accuracy: 0.9669 - loss: 0.0987 - val_accuracy: 0.7857 - val_loss: 1.1652
# Epoch 48/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 36s 46ms/step - accuracy: 0.9663 - loss: 0.1016 - val_accuracy: 0.7709 - val_loss: 1.2531
# Epoch 49/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 36s 46ms/step - accuracy: 0.9687 - loss: 0.0953 - val_accuracy: 0.7611 - val_loss: 1.3790
# Epoch 50/50
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 36s 46ms/step - accuracy: 0.9659 - loss: 0.1001 - val_accuracy: 0.7687 - val_loss: 1.2697
# Epoch 1/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 48ms/step - accuracy: 0.9709 - loss: 0.0829 - val_accuracy: 0.7940 - val_loss: 1.2027
# Epoch 2/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 39s 50ms/step - accuracy: 0.9753 - loss: 0.0746 - val_accuracy: 0.7954 - val_loss: 1.1944
# Epoch 3/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 37s 46ms/step - accuracy: 0.9774 - loss: 0.0663 - val_accuracy: 0.7967 - val_loss: 1.1993
# Epoch 4/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 37s 47ms/step - accuracy: 0.9777 - loss: 0.0650 - val_accuracy: 0.7971 - val_loss: 1.2072
# Epoch 5/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 45ms/step - accuracy: 0.9777 - loss: 0.0607 - val_accuracy: 0.7972 - val_loss: 1.2005
# Epoch 6/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 45ms/step - accuracy: 0.9793 - loss: 0.0607 - val_accuracy: 0.7975 - val_loss: 1.2054
# Epoch 7/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 36s 46ms/step - accuracy: 0.9795 - loss: 0.0597 - val_accuracy: 0.7991 - val_loss: 1.2130
# Epoch 8/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 43ms/step - accuracy: 0.9824 - loss: 0.0516 - val_accuracy: 0.7995 - val_loss: 1.2204
# Epoch 9/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 36s 46ms/step - accuracy: 0.9811 - loss: 0.0559 - val_accuracy: 0.7991 - val_loss: 1.2203
# Epoch 10/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 44ms/step - accuracy: 0.9836 - loss: 0.0489 - val_accuracy: 0.7999 - val_loss: 1.2256
# Epoch 11/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 44ms/step - accuracy: 0.9815 - loss: 0.0523 - val_accuracy: 0.7996 - val_loss: 1.2303
# Epoch 12/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 37s 47ms/step - accuracy: 0.9839 - loss: 0.0478 - val_accuracy: 0.8008 - val_loss: 1.2379
# Epoch 13/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 43ms/step - accuracy: 0.9837 - loss: 0.0452 - val_accuracy: 0.7999 - val_loss: 1.2391
# Epoch 14/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 36s 46ms/step - accuracy: 0.9832 - loss: 0.0473 - val_accuracy: 0.8001 - val_loss: 1.2414
# Epoch 15/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 45ms/step - accuracy: 0.9839 - loss: 0.0500 - val_accuracy: 0.7998 - val_loss: 1.2493
# Epoch 16/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 45ms/step - accuracy: 0.9840 - loss: 0.0462 - val_accuracy: 0.8006 - val_loss: 1.2534
# Epoch 17/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 36s 46ms/step - accuracy: 0.9853 - loss: 0.0438 - val_accuracy: 0.8007 - val_loss: 1.2532
# Epoch 18/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 34s 44ms/step - accuracy: 0.9848 - loss: 0.0442 - val_accuracy: 0.8009 - val_loss: 1.2556
# Epoch 19/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 37s 47ms/step - accuracy: 0.9844 - loss: 0.0439 - val_accuracy: 0.8007 - val_loss: 1.2610
# Epoch 20/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 37s 48ms/step - accuracy: 0.9860 - loss: 0.0414 - val_accuracy: 0.8009 - val_loss: 1.2623
# Final Test Loss: 1.2623
# Final Test Accuracy: 0.8009
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step
# Precision: 0.8004
# Recall: 0.8009
# F1 Score: 0.8005

# %%
import tensorflow as tf
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.models import Sequential
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import confusion_matrix, precision_score, recall_score, f1_score
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Define the custom model architecture
def create_custom_model():
    model = Sequential([
        Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=(32, 32, 3)),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2, 2)),
        
        Conv2D(64, (3, 3), activation='relu', padding='same'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2, 2)),
        
        Conv2D(128, (3, 3), activation='relu', padding='same'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2, 2)),
        
        Flatten(),
        Dense(256, activation='relu'),
        Dropout(0.5),  # Added dropout to help with regularization
        Dense(10, activation='softmax')  # CIFAR-10 has 10 classes
    ])
    
    return model

# Create the model instance
model = create_custom_model()

# Print the model summary
model.summary()

# Load CIFAR-10 dataset
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# Normalize the data
x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0

# One-hot encode the labels
y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

# Compile the model for initial training
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model for 50 epochs
history_initial = model.fit(x_train, y_train, epochs=100, batch_size=64, validation_data=(x_test, y_test))

# Compile the model for fine-tuning with a reduced learning rate
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5), loss='categorical_crossentropy', metrics=['accuracy'])

# Fine-tune the model for additional 20 epochs
history_fine_tune = model.fit(x_train, y_train, epochs=20, batch_size=64, validation_data=(x_test, y_test))

# Evaluate the model on the test dataset
test_loss, test_accuracy = model.evaluate(x_test, y_test, verbose=0)
print(f"Final Test Loss: {test_loss:.4f}")
print(f"Final Test Accuracy: {test_accuracy:.4f}")

# Combine histories for plotting
history_combined = {
    'loss': history_initial.history['loss'] + history_fine_tune.history['loss'],
    'val_loss': history_initial.history['val_loss'] + history_fine_tune.history['val_loss'],
    'accuracy': history_initial.history['accuracy'] + history_fine_tune.history['accuracy'],
    'val_accuracy': history_initial.history['val_accuracy'] + history_fine_tune.history['val_accuracy'],
}

# Plot Loss
plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
plt.plot(history_combined['loss'], label='Train Loss')
plt.plot(history_combined['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()

# Plot Accuracy
plt.subplot(1, 2, 2)
plt.plot(history_combined['accuracy'], label='Train Accuracy')
plt.plot(history_combined['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

plt.tight_layout()
plt.show()

# Predict on the test set
y_pred = model.predict(x_test)
y_pred_classes = np.argmax(y_pred, axis=1)
y_test_classes = np.argmax(y_test, axis=1)

# Generate confusion matrix
conf_matrix = confusion_matrix(y_test_classes, y_pred_classes)

# Plot confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=range(10), yticklabels=range(10))
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# Calculate detailed metrics
precision = precision_score(y_test_classes, y_pred_classes, average='weighted', zero_division=1)
recall = recall_score(y_test_classes, y_pred_classes, average='weighted', zero_division=1)
f1 = f1_score(y_test_classes, y_pred_classes, average='weighted', zero_division=1)

# Print the metrics
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_6 (Conv2D)               │ (None, 32, 32, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 16, 16, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 16, 16, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 16, 16, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 8, 8, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_8 (Conv2D)               │ (None, 8, 8, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 8, 8, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_8 (MaxPooling2D)  │ (None, 4, 4, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_4 (Flatten)             │ (None, 2048)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 256)            │       524,544 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 621,258 (2.37 MB)
#  Trainable params: 620,810 (2.37 MB)
#  Non-trainable params: 448 (1.75 KB)
# Epoch 1/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 48ms/step - accuracy: 0.3983 - loss: 1.7848 - val_accuracy: 0.4966 - val_loss: 1.4833
# Epoch 2/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 36s 46ms/step - accuracy: 0.5908 - loss: 1.1580 - val_accuracy: 0.6220 - val_loss: 1.1128
# Epoch 3/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 38s 49ms/step - accuracy: 0.6637 - loss: 0.9527 - val_accuracy: 0.6133 - val_loss: 1.1222
# Epoch 4/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 37s 47ms/step - accuracy: 0.7096 - loss: 0.8315 - val_accuracy: 0.7176 - val_loss: 0.8199
# Epoch 5/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 37s 47ms/step - accuracy: 0.7477 - loss: 0.7287 - val_accuracy: 0.6502 - val_loss: 1.0564
# Epoch 6/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 37s 47ms/step - accuracy: 0.7781 - loss: 0.6393 - val_accuracy: 0.7579 - val_loss: 0.7093
# Epoch 7/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 36s 46ms/step - accuracy: 0.7966 - loss: 0.5822 - val_accuracy: 0.7275 - val_loss: 0.8211
# Epoch 8/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 36s 47ms/step - accuracy: 0.8112 - loss: 0.5317 - val_accuracy: 0.7570 - val_loss: 0.7498
# Epoch 9/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 37s 47ms/step - accuracy: 0.8345 - loss: 0.4692 - val_accuracy: 0.7587 - val_loss: 0.7382
# Epoch 10/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 39s 50ms/step - accuracy: 0.8455 - loss: 0.4395 - val_accuracy: 0.7364 - val_loss: 0.8513
# Epoch 11/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 37s 47ms/step - accuracy: 0.8576 - loss: 0.4042 - val_accuracy: 0.7329 - val_loss: 0.8682
# Epoch 12/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 37s 47ms/step - accuracy: 0.8725 - loss: 0.3598 - val_accuracy: 0.7502 - val_loss: 0.8630
# Epoch 13/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 45ms/step - accuracy: 0.8784 - loss: 0.3417 - val_accuracy: 0.7304 - val_loss: 1.0860
# Epoch 14/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 45ms/step - accuracy: 0.8914 - loss: 0.3117 - val_accuracy: 0.7457 - val_loss: 0.9499
# Epoch 15/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 37s 48ms/step - accuracy: 0.9002 - loss: 0.2893 - val_accuracy: 0.7299 - val_loss: 1.0721
# Epoch 16/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 37s 47ms/step - accuracy: 0.8995 - loss: 0.2766 - val_accuracy: 0.7827 - val_loss: 0.8019
# Epoch 17/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 38s 48ms/step - accuracy: 0.9067 - loss: 0.2624 - val_accuracy: 0.7783 - val_loss: 0.8380
# Epoch 18/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 39s 50ms/step - accuracy: 0.9141 - loss: 0.2410 - val_accuracy: 0.7700 - val_loss: 0.9900
# Epoch 19/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 36s 46ms/step - accuracy: 0.9175 - loss: 0.2362 - val_accuracy: 0.7650 - val_loss: 0.9913
# Epoch 20/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 37s 47ms/step - accuracy: 0.9227 - loss: 0.2199 - val_accuracy: 0.7661 - val_loss: 1.0199
# Epoch 21/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 39s 50ms/step - accuracy: 0.9295 - loss: 0.1992 - val_accuracy: 0.7690 - val_loss: 0.9374
# Epoch 22/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 36s 46ms/step - accuracy: 0.9306 - loss: 0.2029 - val_accuracy: 0.7567 - val_loss: 1.0769
# Epoch 23/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 36s 46ms/step - accuracy: 0.9318 - loss: 0.1947 - val_accuracy: 0.7748 - val_loss: 1.0395
# Epoch 24/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 36s 47ms/step - accuracy: 0.9353 - loss: 0.1887 - val_accuracy: 0.7717 - val_loss: 0.9805
# Epoch 25/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 35s 44ms/step - accuracy: 0.9397 - loss: 0.1743 - val_accuracy: 0.7743 - val_loss: 1.0975
# Epoch 26/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 53ms/step - accuracy: 0.9427 - loss: 0.1649 - val_accuracy: 0.7345 - val_loss: 1.5201
# Epoch 27/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 39s 50ms/step - accuracy: 0.9398 - loss: 0.1732 - val_accuracy: 0.7743 - val_loss: 1.0834
# Epoch 28/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 39s 50ms/step - accuracy: 0.9434 - loss: 0.1624 - val_accuracy: 0.7772 - val_loss: 1.0734
# Epoch 29/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 39s 49ms/step - accuracy: 0.9447 - loss: 0.1555 - val_accuracy: 0.7777 - val_loss: 1.1392
# Epoch 30/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 39s 50ms/step - accuracy: 0.9498 - loss: 0.1491 - val_accuracy: 0.7664 - val_loss: 1.1574
# Epoch 31/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 38s 48ms/step - accuracy: 0.9487 - loss: 0.1483 - val_accuracy: 0.7784 - val_loss: 1.1796
# Epoch 32/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 39s 49ms/step - accuracy: 0.9535 - loss: 0.1350 - val_accuracy: 0.7675 - val_loss: 1.1436
# Epoch 33/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 40s 52ms/step - accuracy: 0.9516 - loss: 0.1428 - val_accuracy: 0.7558 - val_loss: 1.2833
# Epoch 34/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 37s 48ms/step - accuracy: 0.9502 - loss: 0.1397 - val_accuracy: 0.7742 - val_loss: 1.1232
# Epoch 35/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 39s 50ms/step - accuracy: 0.9533 - loss: 0.1336 - val_accuracy: 0.7775 - val_loss: 1.1557
# Epoch 36/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 38s 49ms/step - accuracy: 0.9570 - loss: 0.1263 - val_accuracy: 0.7808 - val_loss: 1.2001
# Epoch 37/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 37s 48ms/step - accuracy: 0.9553 - loss: 0.1280 - val_accuracy: 0.7736 - val_loss: 1.2062
# Epoch 38/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 39s 50ms/step - accuracy: 0.9603 - loss: 0.1148 - val_accuracy: 0.7758 - val_loss: 1.2808
# Epoch 39/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 39s 50ms/step - accuracy: 0.9590 - loss: 0.1190 - val_accuracy: 0.7873 - val_loss: 1.1438
# Epoch 40/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 38s 49ms/step - accuracy: 0.9603 - loss: 0.1181 - val_accuracy: 0.7712 - val_loss: 1.4895
# Epoch 41/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 39s 50ms/step - accuracy: 0.9605 - loss: 0.1160 - val_accuracy: 0.7924 - val_loss: 1.1703
# Epoch 42/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 38s 48ms/step - accuracy: 0.9612 - loss: 0.1150 - val_accuracy: 0.7891 - val_loss: 1.1867
# Epoch 43/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 39s 50ms/step - accuracy: 0.9646 - loss: 0.1046 - val_accuracy: 0.7822 - val_loss: 1.2135
# Epoch 44/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 40s 51ms/step - accuracy: 0.9629 - loss: 0.1102 - val_accuracy: 0.7630 - val_loss: 1.3168
# Epoch 45/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 39s 50ms/step - accuracy: 0.9625 - loss: 0.1098 - val_accuracy: 0.7816 - val_loss: 1.0784
# Epoch 46/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 39s 50ms/step - accuracy: 0.9655 - loss: 0.0997 - val_accuracy: 0.7762 - val_loss: 1.3784
# Epoch 47/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 39s 50ms/step - accuracy: 0.9656 - loss: 0.0973 - val_accuracy: 0.7841 - val_loss: 1.2956
# Epoch 48/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 38s 49ms/step - accuracy: 0.9658 - loss: 0.0990 - val_accuracy: 0.7794 - val_loss: 1.3450
# Epoch 49/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 52ms/step - accuracy: 0.9684 - loss: 0.0975 - val_accuracy: 0.7701 - val_loss: 1.3001
# Epoch 50/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 39s 50ms/step - accuracy: 0.9679 - loss: 0.0940 - val_accuracy: 0.7795 - val_loss: 1.4663
# Epoch 51/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 39s 49ms/step - accuracy: 0.9676 - loss: 0.0969 - val_accuracy: 0.7791 - val_loss: 1.4038
# Epoch 52/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 38s 48ms/step - accuracy: 0.9677 - loss: 0.0944 - val_accuracy: 0.7452 - val_loss: 1.3849
# Epoch 53/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 40s 51ms/step - accuracy: 0.9696 - loss: 0.0915 - val_accuracy: 0.7809 - val_loss: 1.2759
# Epoch 54/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 37s 48ms/step - accuracy: 0.9684 - loss: 0.0919 - val_accuracy: 0.7795 - val_loss: 1.4124
# Epoch 55/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 36s 46ms/step - accuracy: 0.9700 - loss: 0.0919 - val_accuracy: 0.7690 - val_loss: 1.5541
# Epoch 56/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 37s 47ms/step - accuracy: 0.9703 - loss: 0.0899 - val_accuracy: 0.7846 - val_loss: 1.2068
# Epoch 57/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 38s 49ms/step - accuracy: 0.9741 - loss: 0.0766 - val_accuracy: 0.7781 - val_loss: 1.3507
# Epoch 58/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 38s 49ms/step - accuracy: 0.9707 - loss: 0.0852 - val_accuracy: 0.7731 - val_loss: 1.3626
# Epoch 59/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 40s 52ms/step - accuracy: 0.9720 - loss: 0.0857 - val_accuracy: 0.7849 - val_loss: 1.3155
# Epoch 60/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 40s 51ms/step - accuracy: 0.9699 - loss: 0.0892 - val_accuracy: 0.7752 - val_loss: 1.4434
# Epoch 61/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 38s 49ms/step - accuracy: 0.9705 - loss: 0.0865 - val_accuracy: 0.7721 - val_loss: 1.2341
# Epoch 62/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 40s 51ms/step - accuracy: 0.9744 - loss: 0.0735 - val_accuracy: 0.7827 - val_loss: 1.5364
# Epoch 63/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 40s 51ms/step - accuracy: 0.9742 - loss: 0.0767 - val_accuracy: 0.7803 - val_loss: 1.3922
# Epoch 64/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 40s 51ms/step - accuracy: 0.9733 - loss: 0.0778 - val_accuracy: 0.7876 - val_loss: 1.4466
# Epoch 65/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 43s 55ms/step - accuracy: 0.9746 - loss: 0.0755 - val_accuracy: 0.7720 - val_loss: 1.4159
# Epoch 66/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 40s 51ms/step - accuracy: 0.9740 - loss: 0.0757 - val_accuracy: 0.7839 - val_loss: 1.3947
# Epoch 67/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 39s 50ms/step - accuracy: 0.9747 - loss: 0.0754 - val_accuracy: 0.7881 - val_loss: 1.5876
# Epoch 68/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 52ms/step - accuracy: 0.9751 - loss: 0.0739 - val_accuracy: 0.7705 - val_loss: 1.6959
# Epoch 69/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 39s 50ms/step - accuracy: 0.9750 - loss: 0.0744 - val_accuracy: 0.7855 - val_loss: 1.4468
# Epoch 70/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 38s 49ms/step - accuracy: 0.9742 - loss: 0.0775 - val_accuracy: 0.7755 - val_loss: 1.3837
# Epoch 71/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 52ms/step - accuracy: 0.9762 - loss: 0.0721 - val_accuracy: 0.7781 - val_loss: 1.4535
# Epoch 72/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 52ms/step - accuracy: 0.9767 - loss: 0.0692 - val_accuracy: 0.7841 - val_loss: 1.3358
# Epoch 73/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 39s 50ms/step - accuracy: 0.9756 - loss: 0.0724 - val_accuracy: 0.7849 - val_loss: 1.4755
# Epoch 74/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 52ms/step - accuracy: 0.9776 - loss: 0.0641 - val_accuracy: 0.7781 - val_loss: 1.4490
# Epoch 75/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 40s 51ms/step - accuracy: 0.9781 - loss: 0.0648 - val_accuracy: 0.7824 - val_loss: 1.4187
# Epoch 76/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 39s 50ms/step - accuracy: 0.9773 - loss: 0.0711 - val_accuracy: 0.7822 - val_loss: 1.5844
# Epoch 77/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 52ms/step - accuracy: 0.9785 - loss: 0.0642 - val_accuracy: 0.7692 - val_loss: 1.4850
# Epoch 78/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 40s 51ms/step - accuracy: 0.9782 - loss: 0.0684 - val_accuracy: 0.7887 - val_loss: 1.4047
# Epoch 79/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 39s 50ms/step - accuracy: 0.9801 - loss: 0.0593 - val_accuracy: 0.7869 - val_loss: 1.5974
# Epoch 80/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 40s 51ms/step - accuracy: 0.9803 - loss: 0.0613 - val_accuracy: 0.7875 - val_loss: 1.5687
# Epoch 81/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 40s 52ms/step - accuracy: 0.9797 - loss: 0.0606 - val_accuracy: 0.7789 - val_loss: 1.7087
# Epoch 82/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 39s 50ms/step - accuracy: 0.9794 - loss: 0.0630 - val_accuracy: 0.7939 - val_loss: 1.3911
# Epoch 83/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 40s 51ms/step - accuracy: 0.9799 - loss: 0.0624 - val_accuracy: 0.7868 - val_loss: 1.5795
# Epoch 84/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 53ms/step - accuracy: 0.9812 - loss: 0.0572 - val_accuracy: 0.7594 - val_loss: 1.4153
# Epoch 85/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 38s 49ms/step - accuracy: 0.9785 - loss: 0.0646 - val_accuracy: 0.7819 - val_loss: 1.5167
# Epoch 86/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 52ms/step - accuracy: 0.9815 - loss: 0.0551 - val_accuracy: 0.7845 - val_loss: 1.4456
# Epoch 87/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 53ms/step - accuracy: 0.9817 - loss: 0.0554 - val_accuracy: 0.7852 - val_loss: 1.3318
# Epoch 88/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 40s 51ms/step - accuracy: 0.9816 - loss: 0.0537 - val_accuracy: 0.7903 - val_loss: 1.5827
# Epoch 89/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 42s 53ms/step - accuracy: 0.9785 - loss: 0.0659 - val_accuracy: 0.7594 - val_loss: 1.6900
# Epoch 90/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 44s 56ms/step - accuracy: 0.9802 - loss: 0.0575 - val_accuracy: 0.7600 - val_loss: 1.6633
# Epoch 91/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 40s 51ms/step - accuracy: 0.9799 - loss: 0.0597 - val_accuracy: 0.7791 - val_loss: 1.4646
# Epoch 92/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 40s 51ms/step - accuracy: 0.9834 - loss: 0.0504 - val_accuracy: 0.7868 - val_loss: 1.6430
# Epoch 93/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 42s 53ms/step - accuracy: 0.9804 - loss: 0.0603 - val_accuracy: 0.7811 - val_loss: 1.3429
# Epoch 94/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 40s 51ms/step - accuracy: 0.9824 - loss: 0.0558 - val_accuracy: 0.7885 - val_loss: 1.5742
# Epoch 95/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 40s 51ms/step - accuracy: 0.9816 - loss: 0.0551 - val_accuracy: 0.7844 - val_loss: 1.4568
# Epoch 96/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 43s 55ms/step - accuracy: 0.9839 - loss: 0.0495 - val_accuracy: 0.7818 - val_loss: 1.4977
# Epoch 97/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 40s 51ms/step - accuracy: 0.9818 - loss: 0.0533 - val_accuracy: 0.7718 - val_loss: 1.5915
# Epoch 98/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 52ms/step - accuracy: 0.9836 - loss: 0.0505 - val_accuracy: 0.7724 - val_loss: 1.8225
# Epoch 99/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 53ms/step - accuracy: 0.9817 - loss: 0.0561 - val_accuracy: 0.7790 - val_loss: 1.6623
# Epoch 100/100
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 52ms/step - accuracy: 0.9846 - loss: 0.0488 - val_accuracy: 0.7780 - val_loss: 1.6244
# Epoch 1/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 47s 56ms/step - accuracy: 0.9826 - loss: 0.0512 - val_accuracy: 0.7891 - val_loss: 1.4668
# Epoch 2/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 39s 50ms/step - accuracy: 0.9843 - loss: 0.0483 - val_accuracy: 0.7930 - val_loss: 1.4549
# Epoch 3/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 52ms/step - accuracy: 0.9858 - loss: 0.0422 - val_accuracy: 0.7932 - val_loss: 1.4600
# Epoch 4/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 42s 54ms/step - accuracy: 0.9878 - loss: 0.0404 - val_accuracy: 0.7941 - val_loss: 1.4664
# Epoch 5/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 40s 52ms/step - accuracy: 0.9875 - loss: 0.0384 - val_accuracy: 0.7945 - val_loss: 1.4675
# Epoch 6/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 42s 53ms/step - accuracy: 0.9874 - loss: 0.0344 - val_accuracy: 0.7950 - val_loss: 1.4722
# Epoch 7/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 42s 53ms/step - accuracy: 0.9879 - loss: 0.0353 - val_accuracy: 0.7951 - val_loss: 1.4692
# Epoch 8/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 40s 51ms/step - accuracy: 0.9899 - loss: 0.0312 - val_accuracy: 0.7958 - val_loss: 1.4813
# Epoch 9/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 52ms/step - accuracy: 0.9898 - loss: 0.0314 - val_accuracy: 0.7963 - val_loss: 1.4956
# Epoch 10/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 52ms/step - accuracy: 0.9900 - loss: 0.0293 - val_accuracy: 0.7971 - val_loss: 1.4952
# Epoch 11/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 39s 50ms/step - accuracy: 0.9902 - loss: 0.0296 - val_accuracy: 0.7967 - val_loss: 1.4931
# Epoch 12/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 52ms/step - accuracy: 0.9892 - loss: 0.0312 - val_accuracy: 0.7975 - val_loss: 1.4991
# Epoch 13/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 42s 53ms/step - accuracy: 0.9909 - loss: 0.0262 - val_accuracy: 0.7975 - val_loss: 1.5043
# Epoch 14/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 41s 52ms/step - accuracy: 0.9905 - loss: 0.0274 - val_accuracy: 0.7982 - val_loss: 1.5064
# Epoch 15/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 42s 54ms/step - accuracy: 0.9907 - loss: 0.0267 - val_accuracy: 0.7982 - val_loss: 1.5113
# Epoch 16/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 42s 54ms/step - accuracy: 0.9914 - loss: 0.0248 - val_accuracy: 0.7972 - val_loss: 1.5265
# Epoch 17/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 40s 51ms/step - accuracy: 0.9918 - loss: 0.0245 - val_accuracy: 0.7979 - val_loss: 1.5224
# Epoch 18/20
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 42s 54ms/step - accuracy: 0.9922 - loss: 0.0243 - val_accuracy: 0.7983 - val_loss: 1.5306
# Epoch 19/20
# 106/782 ━━━━━━━━━━━━━━━━━━━━ 33s 49ms/step - accuracy: 0.9933 - loss: 0.0244
