# %%
import tensorflow as tf
from tensorflow.keras import datasets, layers, models, Input
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import seaborn as sns
import time  # To measure training time

# Function to calculate evaluation metrics
def calculate_metrics(y_true, y_pred):
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, average='macro', zero_division=1)
    recall = recall_score(y_true, y_pred, average='macro', zero_division=1)
    f1 = f1_score(y_true, y_pred, average='macro', zero_division=1)
    return accuracy, precision, recall, f1

# Function to plot confusion matrix
def plot_confusion_matrix(y_true, y_pred, classes):
    cm = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=classes, yticklabels=classes)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Confusion Matrix')
    plt.show()

# Check available devices
physical_devices = tf.config.list_physical_devices()
if "GPU" in [device.device_type for device in physical_devices]:
    device_info = "GPU acceleration in place powered by TensorFlow (GPU)"
else:
    device_info = "Using CPU... Best of luck..."
print(device_info)

# Load CIFAR-10 dataset
(x_train, y_train), (x_test, y_test) = datasets.cifar10.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

# Data augmentation
datagen = ImageDataGenerator(
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True
)
datagen.fit(x_train)

# Define the VGG16 model
base_model = tf.keras.applications.VGG16(include_top=False, weights='imagenet', input_shape=(32, 32, 3))
base_model.trainable = False  # Freeze the pre-trained weights

# Adding classification layers on top
flatten_layer = layers.Flatten()
dense_layer = layers.Dense(256, activation='relu')
dropout_layer = layers.Dropout(0.5)
output_layer = layers.Dense(10, activation='softmax')

# Construct the model
inputs = Input(shape=(32, 32, 3))
x = base_model(inputs, training=False)
x = flatten_layer(x)
x = dense_layer(x)
x = dropout_layer(x)
outputs = output_layer(x)
model = models.Model(inputs, outputs)

# Compile the model
optimizer = 'adam'
model.compile(optimizer=optimizer,
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# Set up early stopping and learning rate reduction on plateau
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=5, min_lr=0.00001)

# Start time for training
start_time = time.time()

# Train the model with augmented data
history = model.fit(datagen.flow(x_train, y_train, batch_size=128),
                    epochs=50,
                    validation_data=(x_test, y_test),
                    callbacks=[early_stopping, reduce_lr])

# End time for training
end_time = time.time()
total_training_time = end_time - start_time
average_epoch_time = total_training_time / len(history.history['loss'])

# Evaluate the model on the test dataset
test_loss, test_accuracy = model.evaluate(x_test, y_test)
print(f'Test accuracy: {test_accuracy:.4f}')
print(f'Test loss: {test_loss:.4f}')

# Plot the training curves
plt.figure(figsize=(12, 5))

# Loss curve
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()

# Accuracy curve
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Training and Validation Accuracy')
plt.legend()

plt.show()

# Make predictions
y_pred = np.argmax(model.predict(x_test), axis=-1)

# Calculate evaluation metrics
accuracy, precision, recall, f1 = calculate_metrics(y_test, y_pred)

# Print detailed statistics
print("Detailed Statistics:")
print(f"Number of Epochs: {len(history.history['loss'])}")
print(f"Optimizer: {optimizer}")
print(f"Learning Rate: Adjusted dynamically with ReduceLROnPlateau")
print(f"Loss Function: Sparse Categorical Crossentropy")
print(f"Metrics: Accuracy")

print(f"Final Test Accuracy: {test_accuracy * 100:.2f}%")
print(f"Final Test Loss: {test_loss:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1 Score: {f1:.2f}")
print(f"Total Training Time: {total_training_time // 60:.0f} minutes, {total_training_time % 60:.2f} seconds")
print(f"Average Time per Epoch: {average_epoch_time:.2f} seconds")

# Plot confusion matrix
classes = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
plot_confusion_matrix(y_test, y_pred, classes)
# Out:
# GPU acceleration in place powered by TensorFlow (GPU)
# 2024-06-10 20:00:37.840373: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1
# 2024-06-10 20:00:37.840405: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2024-06-10 20:00:37.840412: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2024-06-10 20:00:37.840436: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-06-10 20:00:37.840453: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# Epoch 1/50
# 2024-06-10 20:00:39.020489: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type GPU is enabled.
# /opt/anaconda3/lib/python3.11/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 39s 97ms/step - accuracy: 0.3436 - loss: 1.8494 - val_accuracy: 0.5272 - val_loss: 1.3581 - learning_rate: 0.0010
# Epoch 2/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 40s 101ms/step - accuracy: 0.4906 - loss: 1.4478 - val_accuracy: 0.5515 - val_loss: 1.2776 - learning_rate: 0.0010
# Epoch 3/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 39s 100ms/step - accuracy: 0.5184 - loss: 1.3691 - val_accuracy: 0.5675 - val_loss: 1.2400 - learning_rate: 0.0010
# Epoch 4/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 42s 106ms/step - accuracy: 0.5290 - loss: 1.3402 - val_accuracy: 0.5727 - val_loss: 1.2189 - learning_rate: 0.0010
# Epoch 5/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 43s 109ms/step - accuracy: 0.5364 - loss: 1.3178 - val_accuracy: 0.5739 - val_loss: 1.2116 - learning_rate: 0.0010
# Epoch 6/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 43s 109ms/step - accuracy: 0.5416 - loss: 1.2978 - val_accuracy: 0.5779 - val_loss: 1.1984 - learning_rate: 0.0010
# Epoch 7/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 42s 106ms/step - accuracy: 0.5488 - loss: 1.2878 - val_accuracy: 0.5848 - val_loss: 1.1778 - learning_rate: 0.0010
# Epoch 8/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 41s 105ms/step - accuracy: 0.5528 - loss: 1.2764 - val_accuracy: 0.5842 - val_loss: 1.1821 - learning_rate: 0.0010
# Epoch 9/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 42s 106ms/step - accuracy: 0.5544 - loss: 1.2645 - val_accuracy: 0.5873 - val_loss: 1.1740 - learning_rate: 0.0010
# Epoch 10/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 41s 104ms/step - accuracy: 0.5577 - loss: 1.2588 - val_accuracy: 0.5880 - val_loss: 1.1692 - learning_rate: 0.0010
# Epoch 11/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 42s 107ms/step - accuracy: 0.5630 - loss: 1.2480 - val_accuracy: 0.5914 - val_loss: 1.1561 - learning_rate: 0.0010
# Epoch 12/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 42s 106ms/step - accuracy: 0.5617 - loss: 1.2337 - val_accuracy: 0.6010 - val_loss: 1.1449 - learning_rate: 0.0010
# Epoch 13/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 41s 105ms/step - accuracy: 0.5693 - loss: 1.2363 - val_accuracy: 0.5947 - val_loss: 1.1483 - learning_rate: 0.0010
# Epoch 14/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 42s 106ms/step - accuracy: 0.5630 - loss: 1.2268 - val_accuracy: 0.5973 - val_loss: 1.1445 - learning_rate: 0.0010
# Epoch 15/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 42s 106ms/step - accuracy: 0.5702 - loss: 1.2321 - val_accuracy: 0.5979 - val_loss: 1.1599 - learning_rate: 0.0010
# Epoch 16/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 42s 106ms/step - accuracy: 0.5714 - loss: 1.2281 - val_accuracy: 0.5946 - val_loss: 1.1438 - learning_rate: 0.0010
# Epoch 17/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 42s 107ms/step - accuracy: 0.5792 - loss: 1.2022 - val_accuracy: 0.6001 - val_loss: 1.1354 - learning_rate: 0.0010
# Epoch 18/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 42s 107ms/step - accuracy: 0.5746 - loss: 1.2121 - val_accuracy: 0.6036 - val_loss: 1.1233 - learning_rate: 0.0010
# Epoch 19/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 41s 104ms/step - accuracy: 0.5795 - loss: 1.2037 - val_accuracy: 0.6025 - val_loss: 1.1354 - learning_rate: 0.0010
# Epoch 20/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 96ms/step - accuracy: 0.5764 - loss: 1.2006 - val_accuracy: 0.6038 - val_loss: 1.1276 - learning_rate: 0.0010
# Epoch 21/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 37s 94ms/step - accuracy: 0.5775 - loss: 1.1976 - val_accuracy: 0.6021 - val_loss: 1.1308 - learning_rate: 0.0010
# Epoch 22/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 37s 95ms/step - accuracy: 0.5792 - loss: 1.1995 - val_accuracy: 0.6085 - val_loss: 1.1202 - learning_rate: 0.0010
# Epoch 23/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 97ms/step - accuracy: 0.5822 - loss: 1.1967 - val_accuracy: 0.6037 - val_loss: 1.1200 - learning_rate: 0.0010
# Epoch 24/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 97ms/step - accuracy: 0.5810 - loss: 1.1975 - val_accuracy: 0.6070 - val_loss: 1.1353 - learning_rate: 0.0010
# Epoch 25/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 97ms/step - accuracy: 0.5828 - loss: 1.1841 - val_accuracy: 0.6052 - val_loss: 1.1187 - learning_rate: 0.0010
# Epoch 26/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 96ms/step - accuracy: 0.5802 - loss: 1.1897 - val_accuracy: 0.6104 - val_loss: 1.1232 - learning_rate: 0.0010
# Epoch 27/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 37s 94ms/step - accuracy: 0.5870 - loss: 1.1777 - val_accuracy: 0.6132 - val_loss: 1.1053 - learning_rate: 0.0010
# Epoch 28/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 96ms/step - accuracy: 0.5859 - loss: 1.1727 - val_accuracy: 0.6092 - val_loss: 1.1161 - learning_rate: 0.0010
# Epoch 29/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 97ms/step - accuracy: 0.5845 - loss: 1.1814 - val_accuracy: 0.6152 - val_loss: 1.1024 - learning_rate: 0.0010
# Epoch 30/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 39s 98ms/step - accuracy: 0.5904 - loss: 1.1774 - val_accuracy: 0.6113 - val_loss: 1.1137 - learning_rate: 0.0010
# Epoch 31/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 97ms/step - accuracy: 0.5925 - loss: 1.1649 - val_accuracy: 0.6073 - val_loss: 1.1233 - learning_rate: 0.0010
# Epoch 32/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 37s 94ms/step - accuracy: 0.5910 - loss: 1.1573 - val_accuracy: 0.6190 - val_loss: 1.1009 - learning_rate: 0.0010
# Epoch 33/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 37s 93ms/step - accuracy: 0.5909 - loss: 1.1700 - val_accuracy: 0.6147 - val_loss: 1.1016 - learning_rate: 0.0010
# Epoch 34/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 97ms/step - accuracy: 0.5937 - loss: 1.1536 - val_accuracy: 0.6139 - val_loss: 1.1010 - learning_rate: 0.0010
# Epoch 35/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 97ms/step - accuracy: 0.5884 - loss: 1.1647 - val_accuracy: 0.6129 - val_loss: 1.1083 - learning_rate: 0.0010
# Epoch 36/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 97ms/step - accuracy: 0.5902 - loss: 1.1580 - val_accuracy: 0.6089 - val_loss: 1.1147 - learning_rate: 0.0010
# Epoch 37/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 37s 95ms/step - accuracy: 0.5936 - loss: 1.1563 - val_accuracy: 0.6132 - val_loss: 1.1034 - learning_rate: 0.0010
# Epoch 38/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 36s 93ms/step - accuracy: 0.5992 - loss: 1.1400 - val_accuracy: 0.6185 - val_loss: 1.0939 - learning_rate: 2.0000e-04
# Epoch 39/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 37s 94ms/step - accuracy: 0.6053 - loss: 1.1250 - val_accuracy: 0.6186 - val_loss: 1.0927 - learning_rate: 2.0000e-04
# Epoch 40/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 96ms/step - accuracy: 0.6056 - loss: 1.1199 - val_accuracy: 0.6235 - val_loss: 1.0885 - learning_rate: 2.0000e-04
# Epoch 41/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 96ms/step - accuracy: 0.6096 - loss: 1.1138 - val_accuracy: 0.6214 - val_loss: 1.0857 - learning_rate: 2.0000e-04
# Epoch 42/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 38s 96ms/step - accuracy: 0.6054 - loss: 1.1192 - val_accuracy: 0.6216 - val_loss: 1.0896 - learning_rate: 2.0000e-04
# Epoch 43/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 37s 95ms/step - accuracy: 0.6100 - loss: 1.1200 - val_accuracy: 0.6212 - val_loss: 1.0887 - learning_rate: 2.0000e-04
# Epoch 44/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 37s 93ms/step - accuracy: 0.6110 - loss: 1.1099 - val_accuracy: 0.6236 - val_loss: 1.0866 - learning_rate: 2.0000e-04
# Epoch 45/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 37s 95ms/step - accuracy: 0.6101 - loss: 1.1136 - val_accuracy: 0.6237 - val_loss: 1.0863 - learning_rate: 2.0000e-04
# Epoch 46/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 36s 91ms/step - accuracy: 0.6060 - loss: 1.1122 - val_accuracy: 0.6236 - val_loss: 1.0857 - learning_rate: 2.0000e-04
# Epoch 47/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 27s 68ms/step - accuracy: 0.6075 - loss: 1.1221 - val_accuracy: 0.6243 - val_loss: 1.0856 - learning_rate: 4.0000e-05
# Epoch 48/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 63ms/step - accuracy: 0.6079 - loss: 1.1180 - val_accuracy: 0.6260 - val_loss: 1.0848 - learning_rate: 4.0000e-05
# Epoch 49/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 62ms/step - accuracy: 0.6171 - loss: 1.1025 - val_accuracy: 0.6253 - val_loss: 1.0848 - learning_rate: 4.0000e-05
# Epoch 50/50
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 25s 63ms/step - accuracy: 0.6157 - loss: 1.1019 - val_accuracy: 0.6255 - val_loss: 1.0849 - learning_rate: 4.0000e-05
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 14ms/step - accuracy: 0.6335 - loss: 1.0771
# Test accuracy: 0.6260
# Test loss: 1.0848
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 4s 11ms/step
# Detailed Statistics:
# Number of Epochs: 50
# Optimizer: adam
# Learning Rate: Adjusted dynamically with ReduceLROnPlateau
# Loss Function: Sparse Categorical Crossentropy
# Metrics: Accuracy
# Final Test Accuracy: 62.60%
# Final Test Loss: 1.08
# Precision: 0.63
# Recall: 0.63
# F1 Score: 0.62
# Total Training Time: 31 minutes, 40.97 seconds
# Average Time per Epoch: 38.02 seconds
